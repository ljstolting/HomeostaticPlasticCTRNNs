# %%
import numpy as np
import matplotlib.pyplot as plt
import CTRNNclass

# %%
size = 3
stepsize = .1
duration = 2000 #in steps
HPgenome = 


C = CTRNN(size,)
timeseries = np.reshape(np.loadtxt("trackneuralstates"),(sizes,circuits,repetitions,int(duration/stepsize)-2))

# %%
time = np.linspace(0,2000,19998)
plt.plot(time,timeseries[15,0,0,:])
plt.plot(time,timeseries[15,0,1,:])
plt.show()
plt.plot(time,timeseries[18,0,0,:])
plt.plot(time,timeseries[18,0,1,:])
plt.show()
