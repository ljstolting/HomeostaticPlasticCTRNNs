# %%
import numpy as np
import matplotlib.pyplot as plt
from CTRNNclass import *

# %%
idx = 26 #idx of circuit you want to visualize

size = 3
stepsize = .1
duration = 1000 #half the desired duration in steps
HPgenome = np.array([.25,.25,.25,.75,.75,.75,40,20,1])
EvolvedGenomes = np.loadtxt('EvolvedPhenotypes.dat')
EvolvedGenomes = EvolvedGenomes.reshape((50,15))
print(EvolvedGenomes[idx])

C = CTRNN(size,stepsize,duration,HPgenome,EvolvedGenomes[idx])
C.runonoff()
C.plot()
C.plotparams()
# Out:
# [  1.        1.        1.       13.0537   -9.75414  15.9994   -9.77462
#  -15.6365   -2.45682   4.15048  11.2279   -1.02853  -6.76811   1.70053
#   13.3844 ]
